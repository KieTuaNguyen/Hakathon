# %% [markdown]
# <img src="https://user-images.githubusercontent.com/7065401/55025843-7d99a280-4fe0-11e9-938a-4879d95c4130.png"
#     style="width:150px; float: right; margin: 0 40px 40px 40px;"></img>
#
# ## Hakathon
# ## Data Visualization with Python
# > _by Shadow Wariors [@GitHub](https://github.com/KieTuaNguyen/Hakathon_Data-Visualization-with-Python.git)._
#
# Welcome to Shadow Wariors presentation ❤️ <br>
# Through this presentation, I hope to be able to give everyone information about the data visualization related to the information of [Bangkok Airbnb Data](https://github.com/KieTuaNguyen/Hakathon_Data-Visualization-with-Python/blob/main/Bangkok%20Airbnb%20Data.pdf).
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ## Overall:
#
# > **Definition of Data Visualization.**
#
# <img src="https://st.a1digihub.com/wp-content/uploads/2019/09/data-visualization-101-2-2.png"
#     style="height: 400px; margin-left: auto; margin-right: auto;"></img>
#
# _Data visualization is representing data in graphical forms such as graphs, charts or using different methods and tools to visualize and illustrate data in the best way. The purpose is to turn data sources into information that is presented in a visual, easy-to-observe, easy-to-understand manner, to clearly convey the full insights from the data to viewers, readers._
#
# _Formats such as line charts, pie charts, column charts, and spreadsheets are traditional forms of data visualization._

# %% [markdown]
# > **The importance of data visualization.**
#
# <img src="https://scontent.fhan14-2.fna.fbcdn.net/v/t1.15752-9/309364132_432839818922857_3690030111804243980_n.png?_nc_cat=100&ccb=1-7&_nc_sid=ae9488&_nc_ohc=deK9Q-3tMv0AX9zygKL&_nc_oc=AQlggGmsRB_z3PG7QaE2rFsS89Ei2F5jNDK0qtoiJ0-BIYJ0MJpvmThbrHhexlFQNfU&_nc_ht=scontent.fhan14-2.fna&oh=03_AdS6J8TFwP78ZHFbTPY-w1823EP2lnqXKNEN0e0gEgYjHQ&oe=637E8153"
#     style="height: 400px; margin-left: auto; margin-right: auto;"></img>
#
# _The right data visualization techniques will help you gain more insight into both your company's activities and that of your customers. While traditional methods do not work effectively with large amounts of data. Because, it will be very difficult to find some data among the huge spreadsheets of business data. This will be very difficult, time consuming and has to be done many times._

# %% [markdown]
# > **Summarise about Bangkok Airbnb.**
#
# <ul>Context
#   <li>Since 2008, guests and hosts have used Airbnb to expand their ability to travel and present a more personal, unique way of experiencing the world. This dataset describes listing activity and metrics in Bangkok, Central Thailand, Thailand in 2022.</li>
# </ul>
#
# <ul>Content
#   <li>This data file includes all the information needed to learn more about the host, available geography, and metrics needed to make predictions and draw conclusions.</li>
# </ul>

# %% [markdown]
# > **Problem Statement.**
# <ul>
#   <li>What can we learn about different hosts and areas?</li>
#   <li>What can we learn from predictions?</li>
#   <li>Which hosts are the busiest and why?</li>
#   <li>Is there any noticeable difference in traffic among different areas and what could be the reason for it?</li>
# </ul>

# %% [markdown]
#  > **Importing necessary libaries for analysing the dataset**

# %%
# Importing necessary libraries for analysing the dataset
import seaborn as sns
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Part 1: Features decription

# %%
path = '/Users/PC/Desktop/Hakathon/'
dataframe1 = pd.read_csv(path + 'listings.csv')
dataframe1.head(0)
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, number_of_reviews_ltm, license]
# Index: []

# %% [markdown]
# `id`: This is the identity number of the property listed by a particular host.</br>
#
# `name`: It stands for the name of the property listed by the host.</br>
#
# `host_id`: It is the identity number of the hosts who have registered on Airbnb website.</br>
#
# `host_name`: These are the names of the hosts who have listed their properties.</br>
#
# `neighbourhood_group`: These are the names of the neighbourhood groups present in the Bangkok.</br>
#
# `neighbourhood`: These are the names of the neighbourhood present in the neighbourhood groups in Bangkok.</br>
#
# `latitude`: These represent the coordinates of latitude of the property listed. </br>
#
# `longitude`: These represent the coordinates of longitude of the property listed.</br>
#
# `room type`: This represent the various types of room listed by host.</br>
#
# `price`: This is the rent of the property listed in USD.</br>
#
# `minimum nights`: This represent the minimum number of nights customer rented the property.</br>
#
# `number_of_reviews`: This represent the number of customers reviewed the property.</br>
#
# `last_review`: This represent the date when the property was last reviewed.</br>
#
# `reviews_per_month`: It is the count of reviews per month which the property received.</br>
#
# `calculated_host_listings_count`: It is the number of listings done by a particular host.</br>
#
# `availability_365`: This represent the number of days the property is available among 365 days.</br>
#
# `number_of_reviews_ltm`: This represent the number of reviews last twelve month.</br>
#
# `license`: This represent the license.</br>

# %% [markdown]
# ## Part 2: Data Exploration:

# %% [markdown]
# ### Undestanding the data

# %% [markdown]
# >Checking the first 5 rows of the dataset.

# %%
path = '/Users/PC/Desktop/Hakathon/'
airbnb = pd.read_csv(path + 'listings.csv')
airbnb.head(5)
# Out:
#          id                                              name    host_id  \
# 0  45305964  Lumpini ville Nakhon in - River view studio Cozy  177103834
# 1   8975471         [Monthly] Plum Condominium Paholyothin 89   46549310
# 2     27934                   Nice room with superb city view     120437
# 3     27979                    Easy going landlord,easy place     120541
# 4  31508092                      Room for rent good and cheap  223483764
#
#    host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0     Thanat                  NaN      Bang Sue  13.83689  100.50330
# 1    Chakree                  NaN    Don Mueang  13.96994  100.61852
# 2     Nuttee                  NaN   Ratchathewi  13.75983  100.54134
# 3        Emy                  NaN       Bang Na  13.66818  100.61674
# 4  Huangseng                  NaN       Bang Na  13.66075  100.57991
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# >Checking the shape of dataset.
# <br>
#
# _The dataset consist of 16640 observations and 18 columns._

# %%
print(f"The shape of Airbnb Dataset is: {airbnb.shape}")
# Out:
# The shape of Airbnb Dataset is: (16640, 18)

# %% [markdown]
# > Checking out 18 columns

# %%
list(airbnb.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license']

# %% [markdown]
# > Checking the datatype of each column

# %%
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# dtype: object

# %% [markdown]
# > Checking for the null value on each column in dataset
# <br>
#
# <ul>
#   <li>Both columns 'neighbourhood_group' and 'license' have largest number of null values which count for 16640.</li>
#   <li>Both columns 'last_review' and 'reviews_per_month' contain fewer number of null values which count for 6573.</li>
# </ul>

# %%
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                  9
# host_id                               0
# host_name                             0
# neighbourhood_group               16640
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        6573
# reviews_per_month                  6573
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           16640
# dtype: int64

# %% [markdown]
# ### Data Cleaning:

# %% [markdown]
# > Dropping the unncessary columns which are 'neighbourhood_group' and 'license'.

# %%
airbnb = airbnb.drop(
    ['neighbourhood_group', 'license'], axis=1)
airbnb.head()
# Out:
#          id                                              name    host_id  \
# 0  45305964  Lumpini ville Nakhon in - River view studio Cozy  177103834
# 1   8975471         [Monthly] Plum Condominium Paholyothin 89   46549310
# 2     27934                   Nice room with superb city view     120437
# 3     27979                    Easy going landlord,easy place     120541
# 4  31508092                      Room for rent good and cheap  223483764
#
#    host_name neighbourhood  latitude  longitude        room_type  price  \
# 0     Thanat      Bang Sue  13.83689  100.50330  Entire home/apt    388
# 1    Chakree    Don Mueang  13.96994  100.61852     Private room   5000
# 2     Nuttee   Ratchathewi  13.75983  100.54134  Entire home/apt   2034
# 3        Emy       Bang Na  13.66818  100.61674     Private room   1405
# 4  Huangseng       Bang Na  13.66075  100.57991     Private room    700
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %% [markdown]
# > Review the dataset after dropping the unncessary columns which are 'neighbourhood_group' and 'license'.

# %%
list(airbnb.columns)
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm']

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
# ## Part 3: Analysis

# %% [markdown]
# > Host with maximum listing

# %%
# The hosts have the most listings on Airbnb
top_host = airbnb.host_name.value_counts().head(10)
top_host
# Out:
# Curry       207
# Noons        91
# K            86
# Pornchai     74
# Gravity      69
# Bee          65
# Alex         64
# Dusadee      62
# Zuzu         59
# George       58
# Name: host_name, dtype: int64

# %%
#setting figure size for future visualizations
sns.set(rc={'figure.figsize': (10, 8)})
sns.set_style('white')

top_host_df = pd.DataFrame(top_host)
top_host_df.reset_index(inplace=True)
top_host_df.rename(columns={'index': 'host_name',
                   'host_name': 'P_Count'}, inplace=True)
top_host_df
# Out:
#   host_name  P_Count
# 0     Curry      207
# 1     Noons       91
# 2         K       86
# 3  Pornchai       74
# 4   Gravity       69
# 5       Bee       65
# 6      Alex       64
# 7   Dusadee       62
# 8      Zuzu       59
# 9    George       58

# %%
viz_1 = sns.barplot(x="host_name", y="P_Count",
                    data=top_host_df, palette='dark:#5A9_r')
viz_1.set_title('Hosts with the most listings in BKK')
viz_1.set_ylabel('Count of listings')
viz_1.set_xlabel('Host Names')
viz_1.set_xticklabels(viz_1.get_xticklabels())
# Out:
# [Text(0, 0, 'Curry'),
#  Text(1, 0, 'Noons'),
#  Text(2, 0, 'K'),
#  Text(3, 0, 'Pornchai'),
#  Text(4, 0, 'Gravity'),
#  Text(5, 0, 'Bee'),
#  Text(6, 0, 'Alex'),
#  Text(7, 0, 'Dusadee'),
#  Text(8, 0, 'Zuzu'),
#  Text(9, 0, 'George')]

# %% [markdown]
# <ul>
#   <li>As shown in the adjacent bar chart, we can see there is a good distribution among the top 10 hosts in Bangkok.</li>
#   <li>The host named Noons has the second-highest number of listings at 91, the value of host named Noons is nearly half less than that of host named Curry.</li>
#   <li>The host named K has the third highest number of listings of 86.</li>
# </ul>

# %% [markdown]
# > Analysis of rental prices

# %%
# Checking the descriptive statistics
airbnb_data_new = airbnb.drop(
    ['last_review', 'reviews_per_month'], axis=1)
airbnb_data_new.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  1.664000e+04  1.664000e+04  16640.000000  16640.000000   16640.000000
# mean   8.753380e+16  1.484973e+08     13.746697    100.561649    2514.712079
# std    2.225392e+17  1.218480e+08      0.050285      0.054060   16154.846054
# min    2.793400e+04  5.892000e+04     13.527300    100.311700       0.000000
# 25%    2.002339e+07  4.049175e+07     13.718508    100.530158     800.000000
# 50%    3.324110e+07  1.229586e+08     13.738270    100.561710    1235.500000
# 75%    4.278576e+07  2.314076e+08     13.761935    100.587710    2000.000000
# max    7.198605e+17  4.801477e+08     13.973550    100.923440  900000.000000
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# count    16640.000000       16640.000000                    16640.000000
# mean        15.197055          15.365084                       12.237500
# ...

# %% [markdown]
# <ul>
# <li>The summary statistics show us that the average price is 2514.71$.
# </li>
# <li>The average minimum nights stay is 15.2 nights, and the average number of reviews is 15.365 per listing.
# </li>
# <li>We also learn that a host has an average of 12.2 places listed and availability averages 242.8 vacant days per year.
# </li>
# <li>Most importantly, the min price is showing as zero and the max price as 900.000$.
# </li>
# <li>Something isn't right with the data, so need to look into this issue and check for outliers.
# </li>
# </ul>

# %%
# Checking for outliers
airbnb_data_new.agg({'price':['mean','median','max','count']})
# Out:
#                 price
# mean      2514.712079
# median    1235.500000
# max     900000.000000
# count    16640.000000

# %% [markdown]
# <ul>
# <li>The minimum value is set as zero, which does not make any sense since there are no free rooms on Airbnb - and the maximum value is set at 900.000$ - which just seems too high.
# </li>
# </ul>
# Notice how the mean is considerably higher than the median. This is an indication that the data is skewed.

# %%
#Plotting the boxplot of the price data.
plt.figure(figsize=(10, 5))
ax = sns.boxplot(y='price', data=airbnb_data_new).set_title(
    'Price Distribution by neighbourhood group')
sns.set_theme(style='white')
plt.xlabel('Neighbourhood')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# As expected there are outliers present in the data. In order to fix this, we will be using the quantile based flooring and capping.
# First, let's print the 10th and 90th percentile of the price column.

# %%
# low quantile
q_low = airbnb_data_new['price'].quantile(0.10)
q_low
# Out:
# 590.0

# %%
#high quantile
q_high = airbnb_data_new['price'].quantile(0.9)
q_high
# Out:
# 3643.0

# %% [markdown]
# <ul>
#   <li>We can see from the adjacent box plot that price data is skewed. There are outliers present in the data.</li>
#   <li>We have eliminated the outliers based on quantile flooring and capping.</li>
#   <li>We have considered price range which falls under the 10th percentile and 90th percentile range.</li>
#   <li>The range is from 590$ to 3643$</li>
# </ul>
#
# After capping and flooring the price data, we get the below shown boxplot which is much cleaner.

# %%
#removing the values below 10th percentile and above 90th percentile
airbnb_data_new = airbnb_data_new.drop(
    airbnb_data_new[airbnb_data_new['price'] < q_low].index)
airbnb_data_new = airbnb_data_new.drop(
    airbnb_data_new[airbnb_data_new['price'] > q_high].index)

#Create a new boxplot and check the result.
plt.figure(figsize=(10, 5))
ax = sns.boxplot(y='price', data=airbnb_data_new).set_title(
    'Price Distribution')
sns.set_theme(style='white')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# > Busiest Host

# %%
#Busiest hosts would be those who have maximum number of reviews as people are booking frequently at those hosts.
busiest_hosts = airbnb.groupby(['host_name', 'host_id', 'room_type',])[
    'number_of_reviews'].max().reset_index()
busiest_hosts = busiest_hosts.sort_values(
    by='number_of_reviews', ascending=False).head(10)
busiest_hosts
# Out:
#        host_name    host_id        room_type  number_of_reviews
# 6140     Suchada  116193397  Entire home/apt               1151
# 4313      Pailin  158545122     Private room                722
# 7444   Wuthiphon   35462876  Entire home/apt                528
# 6756  Themustang   30963587       Hotel room                484
# 656          Bee    3346331  Entire home/apt                461
# 550     Auttapon   48491149     Private room                449
# 1532        Evan    1927968  Entire home/apt                426
# 124         Alex   19266319  Entire home/apt                379
# 825          Bua    2389272     Private room                377
# 3165         Mam   15218917  Entire home/apt                371

# %%
# Visualising the busiest hosts data through bar plot.
host_name = busiest_hosts['host_name']
reviews = busiest_hosts['number_of_reviews']
plt.title('Busiest Hosts', {'fontsize': 18})
plt.xlabel('Host Names', {'fontsize': 18})
plt.ylabel('Number of reviews', {'fontsize': 18})
plt.bar(host_name, reviews)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# <ul>
#   <li>The adjacent bar plot shows the top 10 hosts with respect to number of reviews.</li>
#   <li>Among them Suchada has highest numbers of reviews and we can assume that Suchada is the busiest host.</li>
#   <li>The top hosts have listed private room, entire home/apt.</li>
# </ul>

# %% [markdown]
# > Most Preferred Room Types

# %%
# Plotting histogram for room types to look for which are most preferred room types.
plt.figure(figsize=(16, 8))
ax = sns.countplot(x='room_type', data=airbnb,
                   order=airbnb['room_type'].value_counts().index)
abs_values = airbnb['room_type'].value_counts(ascending=False)
rel_values = airbnb['room_type'].value_counts(
    ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]
# puts the labels on the bars
ax.bar_label(container=ax.containers[0], labels=lbls)
ax.set_title('Number of Listings by Room Type')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <ul>
#   <li>Looking at the adjacent histogram, we can say that there are 4 room types listed in the entire dataset namely Entire home/apt, Private room, Shared room and Hotel room.</li>
#   <li>Among this types the most preferred room type is Entire home/apt as well as Entire home/apt.</li>
#   <li>Shared room is least preferred by people.</li>
# </ul>

# %% [markdown]
# > Map of the Bangkok city

# %%
# Using the neighbourhood geo to create a map of the neighbourhoods in the city of Bangkok.
airbnb_neighbourhoods_geo = gpd.read_file("neighbourhoods.geojson")
viz_1 = airbnb_neighbourhoods_geo.plot()

# %% [markdown]
# > Top 10 neighbourhoods with the most listing

# %%
# Lets find the top 10 neighbourhoods with most listings
df1 = airbnb_data_new.groupby(['neighbourhood'])['id'].count().nlargest(10)
df1
# Out:
# neighbourhood
# Khlong Toei     1835
# Vadhana         1677
# Ratchathewi      924
# Huai Khwang      901
# Bang Rak         673
# Sathon           651
# Bang Na          498
# Phra Khanong     482
# Chatu Chak       453
# Phra Nakhon      395
# Name: id, dtype: int64

# %%
# Visualizing the top 10 neighbourhood listings through bar plot
plt.figure(figsize=(12, 6))
x = list(df1.index)
y = list(df1.values)
x.reverse()
y.reverse()

plt.title("Top 10 Neighbourhoods with the Most Listings", {'fontsize': 18})
plt.xlabel("Total Listings", {'fontsize': 18})
plt.ylabel("Neighbourhood", {'fontsize': 18})


plt.barh(x, y)
plt.show()

# %% [markdown]
# <ul>
#   <li>From the various Neighbourhoods top 10 Neighbourhoods are listed in the chart.</li>
#   <li>Khlong Toei has the highest numbers of listing which is around 1835.</li>
# </ul>

# %% [markdown]
# > Grabbing top 10 neighbourhoods for sub-dataframe

# %%
#grabbing top 10 neighbourhoods for sub-dataframe
sub_1 = airbnb.loc[airbnb['neighbourhood'].isin(['Khlong Toei', 'Vadhana', 'Huai Khwang', 'Sathon',
                                                                   'Phra Nakhon', 'Phra Khanong', 'Chatu Chak', 'Bang Na', 'Bang Rak', 'Ratchathewi'])]
#using catplot to represent multiple interesting attributes together and a count
viz_2 = sns.catplot(x='neighbourhood', hue='neighbourhood',
                    col='room_type', data=sub_1, kind='count')
viz_2.set_xticklabels(rotation=90)

# %% [markdown]
# > Scatter plot of room type

# %%
#Scatter plot of room type
plt.figure(figsize=(10, 6))
sns.scatterplot(data=airbnb, x=airbnb.longitude,
                y=airbnb.latitude, hue=airbnb.room_type)
plt.show()

# %% [markdown]
# > Using countplot to visualize the number of Airbnbs in each neighbourhood

# %%
# using countplot to visualize the number of Airbnbs in each neighbourhood
plt.figure(figsize=(24, 8))
ax = sns.countplot(x='neighbourhood', data=airbnb,
                   order=airbnb['neighbourhood'].value_counts().index)
abs_values = airbnb['neighbourhood'].value_counts(
    ascending=False).values
ax.bar_label(container=ax.containers[0], labels=abs_values)

ax.set_title('Number of Listings by Neighbourhood')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Part 4: Interacting with data

# %% [markdown]
# text

# %% [markdown]
# ## Conclusion
#
# text

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
